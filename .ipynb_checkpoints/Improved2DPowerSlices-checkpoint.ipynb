# %%
# use the same interpreter the notebook is running
import sys; print(sys.executable)

# %pip install --upgrade pip
# %pip install numpy matplotlib
# (optional) MATLAB engine wheel for R2025a:
# %pip install matlabengine==25.1.2
# Out:
# C:\Users\13523\venvs\lab\Scripts\python.exe
# Requirement already satisfied: pip in c:\users\13523\venvs\lab\lib\site-packages (25.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\users\13523\venvs\lab\lib\site-packages (2.2.6)
# Requirement already satisfied: matplotlib in c:\users\13523\venvs\lab\lib\site-packages (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\13523\venvs\lab\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\13523\venvs\lab\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\13523\venvs\lab\lib\site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\13523\venvs\lab\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\13523\venvs\lab\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\13523\venvs\lab\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\13523\venvs\lab\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\13523\venvs\lab\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\13523\venvs\lab\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matlabengine==25.1.2 in c:\users\13523\venvs\lab\lib\site-packages (25.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matlab.engine

# %%
#write data to python file

eng = matlab.engine.start_matlab()
eng.eval("load('shared.mat')", nargout=0)   # or run your script to create y_accum
y_accum = np.array(eng.workspace['y_accum'])
Xgrid   = np.array(eng.workspace['Xgrid'])
Ygrid   = np.array(eng.workspace['Ygrid'])
Zgrid   = np.array(eng.workspace['Zgrid'])

# %%
#size sanity check
def print_size(name):
    try:
        v = eng.workspace[name]
    except KeyError:
        print(f"{name}: not found")
        return
    sz = tuple(np.array(eng.size(v, nargout=1)).ravel().astype(int))
    print(f"{name}: {sz}")

print_size("y_accum")
print_size("Xgrid")
print_size("Ygrid")
print_size("Zgrid")
# Out:
# y_accum: (np.int64(60), np.int64(60), np.int64(25))
# Xgrid: (np.int64(60), np.int64(1), np.int64(60))
# Ygrid: (np.int64(60), np.int64(1), np.int64(60))
# Zgrid: (np.int64(60), np.int64(1), np.int64(60))

# %%
mag = np.abs(y_accum)
eps = 1e-12
N = y_accum.shape[2]                 # number of images
imgs_db = 20*np.log10(mag / (mag.max() + eps) + eps)

ymin, ymax = float(Ygrid.min()), float(Ygrid.max())
zmin, zmax = float(Zgrid.min()), float(Zgrid.max())

vmin, vmax = np.percentile(imgs_db, 5), np.percentile(imgs_db, 99)

# %%
for i in range(N):
    img = imgs_db[:, :, i]           # NOT y_accum(:,:,i)
    val = np.nanmin(np.abs(img))     # magnitude; ignores NaNs
    
    print(f"image {i+1} min is {val:.2f}\n")
    print(f"image {i+1} max is {np.nanmax(np.abs(img))}\n")
# Out:
# image 1 min is 16.92
#
# image 1 max is 65.38897705078125
#
# image 2 min is 14.11
#
# image 2 max is 64.27552032470703
#
# image 3 min is 7.50
#
# image 3 max is 72.91841125488281
#
# image 4 min is 3.13
#
# image 4 max is 78.13529968261719
#
# image 5 min is 20.30
#
# image 5 max is 74.99131774902344
#
# image 6 min is 19.50
#
# image 6 max is 73.2984848022461
#
# image 7 min is 9.42
#
# image 7 max is 77.21770477294922
#
# image 8 min is 0.00
#
# image 8 max is 68.80729675292969
#
# image 9 min is 8.18
#
# image 9 max is 65.81063079833984
#
# image 10 min is 12.17
#
# image 10 max is 61.9599609375
#
# image 11 min is 11.51
#
# image 11 max is 62.08484649658203
#
# image 12 min is 3.41
#
# image 12 max is 64.14258575439453
#
# image 13 min is 12.84
#
# image 13 max is 72.82234954833984
#
# image 14 min is 20.53
#
# image 14 max is 88.19149017333984
#
# image 15 min is 21.92
#
# image 15 max is 79.59506225585938
#
# image 16 min is 21.23
#
# image 16 max is 67.79151916503906
#
# image 17 min is 18.95
#
# image 17 max is 76.02913665771484
#
# image 18 min is 15.46
#
# image 18 max is 65.02035522460938
#
# image 19 min is 17.95
#
# image 19 max is 68.55619049072266
#
# image 20 min is 3.05
#
# image 20 max is 72.04100799560547
#
# image 21 min is 17.07
#
# image 21 max is 65.67237091064453
#
# image 22 min is 17.76
#
# image 22 max is 67.7662124633789
#
# image 23 min is 15.03
#
# image 23 max is 72.69656372070312
#
# image 24 min is 21.73
#
# image 24 max is 67.06767272949219
#
# image 25 min is 15.51
#
# image 25 max is 76.944580078125

# %%
#zero-ing kernel
N = y_accum.shape[2]
mask = imgs_db >= -30
imgs_db = imgs_db * mask

# %%
#plotting
fig, axes = plt.subplots(5, 5, figsize=(15, 15), constrained_layout=True)
for i, ax in enumerate(axes.flat):
    im = ax.imshow(imgs_db[:, :, i].T,
                   origin='lower', aspect='equal',
                   extent=[ymin, ymax, zmin, zmax],
                   vmin=vmin, vmax=vmax)
    ax.set_title(f"Scan {i+1}")
    ax.set_xlabel("Y"); ax.set_ylabel("Z")
    #Axes.set_ylim(20,30); Axes.set_xlim(20,30);

fig.colorbar(im, ax=axes, shrink=0.65, label="Power [dB]")
plt.show()
